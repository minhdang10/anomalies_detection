# %%
# connect to snowflake

# %reload_ext snowflakes
# %snowflakes FUSION_FDR_ETL_USER FsW@1fDrR pitneybowes.us-east-1

# %%
# %%snowflakes DFW1
#
# SELECT
#     PARCELKEY, FACILITYNAME, MACHINEID, CREATIONTIME, LENGTH, WIDTH, HEIGHT, WEIGHT
# FROM
#     "FDR_DWH_DB_PROD"."PARCELAUTOMATION"."PARCEL"
# WHERE
#     CREATIONTIME >= '2021-05-01' AND CREATIONTIME < '2021-05-16' AND FACILITYNAME = 'DFW4' AND LENGTH != 0 AND WEIGHT != 0;
# Out:
#          PARCELKEY FACILITYNAME  MACHINEID            CREATIONTIME  LENGTH  \
# 0        718936886         DFW4          7 2021-05-11 20:40:27.470   241.0
# 1        718921236         DFW4          7 2021-05-11 20:13:13.910   399.0
# 2        718911692         DFW4          7 2021-05-11 20:00:58.550   300.0
# 3        718935848         DFW4          7 2021-05-11 20:39:03.213   314.0
# 4        718975693         DFW4          7 2021-05-11 21:31:22.053   388.0
# ...            ...          ...        ...                     ...     ...
# 1071470  709790105         DFW4          7 2021-05-01 00:02:20.110   367.0
# 1071471  709823493         DFW4          8 2021-05-01 00:37:29.203   315.0
# 1071472  709821610         DFW4          7 2021-05-01 00:36:02.850   210.0
# 1071473  709861029         DFW4          7 2021-05-01 01:41:21.230   480.0
# 1071474  709803266         DFW4          7 2021-05-01 00:18:03.120   277.0
#
#          WIDTH  HEIGHT  WEIGHT
# 0        120.0   151.0  1350.0
# ...

# %%
DFW1.to_csv('DFW1.csv')

# %%
# %%snowflakes DFW2
#
# SELECT
#     PARCELKEY, FACILITYNAME, MACHINEID, CREATIONTIME, LENGTH, WIDTH, HEIGHT, WEIGHT
# FROM
#     "FDR_DWH_DB_PROD"."PARCELAUTOMATION"."PARCEL"
# WHERE
#     CREATIONTIME >= '2021-05-16' AND CREATIONTIME < '2021-06-01' AND FACILITYNAME = 'DFW4' AND LENGTH != 0 AND WEIGHT != 0;
# Out:
#          PARCELKEY FACILITYNAME  MACHINEID            CREATIONTIME  LENGTH  \
# 0        728502701         DFW4          7 2021-05-20 23:13:09.407   336.0
# 1        728497949         DFW4          7 2021-05-20 23:09:01.930   310.0
# 2        728534397         DFW4          7 2021-05-20 23:43:37.007   236.0
# 3        728604950         DFW4          7 2021-05-21 00:48:13.167   235.0
# 4        728422039         DFW4          8 2021-05-20 21:51:27.750   193.0
# ...            ...          ...        ...                     ...     ...
# 1155740  727090782         DFW4          7 2021-05-19 18:16:01.143   198.0
# 1155741  726928611         DFW4          7 2021-05-19 16:10:56.237   293.0
# 1155742  727115229         DFW4          7 2021-05-19 18:35:27.960   271.0
# 1155743  727067648         DFW4          7 2021-05-19 17:59:20.513   301.0
# 1155744  727001778         DFW4          7 2021-05-19 17:17:52.430   368.0
#
#          WIDTH  HEIGHT  WEIGHT
# 0         55.0   229.0  1054.0
# ...

# %%
DFW2.to_csv('DFW2.csv')

# %%
# %%snowflakes DFW3
#
# SELECT
#     PARCELKEY, FACILITYNAME, MACHINEID, CREATIONTIME, LENGTH, WIDTH, HEIGHT, WEIGHT
# FROM
#     "FDR_DWH_DB_PROD"."PARCELAUTOMATION"."PARCEL"
# WHERE
#     CREATIONTIME >= '2021-06-01' AND CREATIONTIME < '2021-06-15' AND FACILITYNAME = 'DFW4' AND LENGTH != 0 AND WEIGHT != 0;
# Out:
#          PARCELKEY FACILITYNAME  MACHINEID            CREATIONTIME  LENGTH  \
# 0        738018826         DFW4          7 2021-06-02 04:48:48.843   216.0
# 1        738055429         DFW4          7 2021-06-02 05:46:04.147   359.0
# 2        738045026         DFW4          7 2021-06-02 05:34:29.700   247.0
# 3        738026961         DFW4          7 2021-06-02 05:12:08.970   257.0
# 4        738045090         DFW4          7 2021-06-02 05:34:03.317   223.0
# ...            ...          ...        ...                     ...     ...
# 1106101  748461148         DFW4          8 2021-06-14 14:43:41.000   286.0
# 1106102  748432048         DFW4          7 2021-06-14 14:15:31.603   349.0
# 1106103  748486194         DFW4          7 2021-06-14 15:06:27.803   320.0
# 1106104  748417711         DFW4          7 2021-06-14 14:02:12.570   258.0
# 1106105  748359413         DFW4          8 2021-06-14 13:09:20.577   198.0
#
#          WIDTH  HEIGHT  WEIGHT
# 0        157.0   159.0   340.0
# ...

# %%
DFW3.to_csv('DFW3.csv')

# %%
# %%snowflakes DFW4
#
# SELECT
#     PARCELKEY, FACILITYNAME, MACHINEID, CREATIONTIME, LENGTH, WIDTH, HEIGHT, WEIGHT
# FROM
#     "FDR_DWH_DB_PROD"."PARCELAUTOMATION"."PARCEL"
# WHERE
#     CREATIONTIME >= '2021-06-15' AND CREATIONTIME < '2021-07-01' AND FACILITYNAME = 'DFW4' AND LENGTH != 0 AND WEIGHT != 0;
# Out:
#          PARCELKEY FACILITYNAME  MACHINEID            CREATIONTIME  LENGTH  \
# 0        753315179         DFW4          8 2021-06-18 18:37:47.667   282.0
# 1        753279801         DFW4          8 2021-06-18 18:10:31.413   462.0
# 2        753269193         DFW4          7 2021-06-18 18:01:46.533   525.0
# 3        753148021         DFW4          7 2021-06-18 16:12:04.420   314.0
# 4        753245961         DFW4          8 2021-06-18 17:43:55.347   248.0
# ...            ...          ...        ...                     ...     ...
# 1372692  758822688         DFW4          7 2021-06-25 12:22:51.883   324.0
# 1372693  758835982         DFW4          7 2021-06-25 12:37:30.523   222.0
# 1372694  758824203         DFW4          7 2021-06-25 12:23:53.250   441.0
# 1372695  758840691         DFW4          7 2021-06-25 12:42:08.150   225.0
# 1372696  758830985         DFW4          7 2021-06-25 12:31:15.587   362.0
#
#          WIDTH  HEIGHT  WEIGHT
# 0        100.0   210.0  707.00
# ...

# %%
DFW4.to_csv('DFW4.csv')

# %%
# %%snowflakes DFW5
#
# SELECT
#     PARCELKEY, FACILITYNAME, MACHINEID, CREATIONTIME, LENGTH, WIDTH, HEIGHT, WEIGHT
# FROM
#     "FDR_DWH_DB_PROD"."PARCELAUTOMATION"."PARCEL"
# WHERE
#     CREATIONTIME >= '2021-04-01' AND CREATIONTIME < '2021-04-15' AND FACILITYNAME = 'DFW4' AND LENGTH != 0 AND WEIGHT != 0;
# Out:
#          PARCELKEY FACILITYNAME  MACHINEID            CREATIONTIME  LENGTH  \
# 0        693791612         DFW4          7 2021-04-13 17:30:18.183   376.0
# 1        693791613         DFW4          8 2021-04-13 17:30:48.557   443.0
# 2        693791621         DFW4          7 2021-04-13 17:29:46.560   266.0
# 3        693791622         DFW4          8 2021-04-13 17:30:49.033   366.0
# 4        693791648         DFW4          7 2021-04-13 17:30:19.720   518.0
# ...            ...          ...        ...                     ...     ...
# 1001729  693478788         DFW4          7 2021-04-13 13:09:19.570   264.0
# 1001730  693478789         DFW4          7 2021-04-13 13:09:19.423   346.0
# 1001731  693478790         DFW4          8 2021-04-13 13:10:53.523   395.0
# 1001732  693478803         DFW4          7 2021-04-13 13:09:20.497   258.0
# 1001733  693478805         DFW4          7 2021-04-13 13:08:48.110   358.0
#
#          WIDTH  HEIGHT  WEIGHT
# 0        153.0   344.0  1058.0
# ...

# %%
DFW5.to_csv('DFW5.csv')

# %%
# %%snowflakes DFW6
#
# SELECT
#     PARCELKEY, FACILITYNAME, MACHINEID, CREATIONTIME, LENGTH, WIDTH, HEIGHT, WEIGHT
# FROM
#     "FDR_DWH_DB_PROD"."PARCELAUTOMATION"."PARCEL"
# WHERE
#     CREATIONTIME >= '2021-04-15' AND CREATIONTIME < '2021-05-01' AND FACILITYNAME = 'DFW4' AND LENGTH != 0 AND WEIGHT != 0;
# Out:
#          PARCELKEY FACILITYNAME  MACHINEID            CREATIONTIME  LENGTH  \
# 0        699484414         DFW4          7 2021-04-20 03:04:25.523   296.0
# 1        699484425         DFW4          8 2021-04-20 03:04:25.727   116.0
# 2        699484427         DFW4          7 2021-04-20 03:04:25.907   296.0
# 3        699484434         DFW4          8 2021-04-20 03:04:26.247   301.0
# 4        699484449         DFW4          7 2021-04-20 03:04:26.753   263.0
# ...            ...          ...        ...                     ...     ...
# 1303303  707538473         DFW4          8 2021-04-28 23:35:11.397   339.0
# 1303304  707635169         DFW4          7 2021-04-29 00:52:10.097   378.0
# 1303305  707538746         DFW4          8 2021-04-28 23:36:25.210   354.0
# 1303306  707479417         DFW4          8 2021-04-28 22:46:05.377   321.0
# 1303307  707530968         DFW4          8 2021-04-28 23:29:20.187   319.0
#
#          WIDTH  HEIGHT    WEIGHT
# 0        123.0   222.0   461.188
# ...

# %%
DFW6.to_csv('DFW6.csv')

# %%
import pandas as pd

DFW = pd.read_csv('DFW1.csv')
DFW2 = pd.read_csv('DFW2.csv')
DFW3 = pd.read_csv('DFW3.csv')
DFW4 = pd.read_csv('DFW4.csv')
DFW5 = pd.read_csv('DFW5.csv')
DFW6 = pd.read_csv('DFW6.csv')

DFW = DFW.append(DFW2)
DFW = DFW.append(DFW3)
DFW = DFW.append(DFW4)
DFW = DFW.append(DFW5)
DFW = DFW.append(DFW6)

DFW.to_csv('dfw.csv')

# %%
# %%snowflakes DFW8
#
# SELECT
#     PARCELKEY, FACILITYNAME, MACHINEID, CREATIONTIME, LENGTH, WIDTH, HEIGHT, WEIGHT
# FROM
#     "FDR_DWH_DB_PROD"."PARCELAUTOMATION"."PARCEL"
# WHERE
#     CREATIONTIME >= '2021-01-15' AND CREATIONTIME < '2021-02-01' AND FACILITYNAME = 'DFW4' AND LENGTH != 0 AND WEIGHT != 0;
# Out:
#         PARCELKEY FACILITYNAME  MACHINEID            CREATIONTIME  LENGTH  \
# 0       626591666         DFW4          8 2021-01-21 19:35:00.897   251.0
# 1       626591670         DFW4          7 2021-01-21 19:35:01.180   313.0
# 2       626591682         DFW4          7 2021-01-21 19:35:33.710   190.0
# 3       626591695         DFW4          8 2021-01-21 19:37:06.557   482.0
# 4       626591696         DFW4          7 2021-01-21 19:35:34.167   457.0
# ...           ...          ...        ...                     ...     ...
# 981168  631003801         DFW4          7 2021-01-27 16:28:48.120   214.0
# 981169  631003802         DFW4          8 2021-01-27 16:28:48.313   193.0
# 981170  631003808         DFW4          7 2021-01-27 16:28:48.580   213.0
# 981171  631003809         DFW4          8 2021-01-27 16:28:48.763   196.0
# 981172  631003812         DFW4          7 2021-01-27 16:28:16.847   224.0
#
#         WIDTH  HEIGHT  WEIGHT
# 0       143.0   179.0  1039.0
# ...

# %%
DFW8.to_csv('DFW8.csv')

# %%
# %%snowflakes DFW9
#
# SELECT
#     PARCELKEY, FACILITYNAME, MACHINEID, CREATIONTIME, LENGTH, WIDTH, HEIGHT, WEIGHT
# FROM
#     "FDR_DWH_DB_PROD"."PARCELAUTOMATION"."PARCEL"
# WHERE
#     CREATIONTIME >= '2021-02-01' AND CREATIONTIME < '2021-02-15' AND FACILITYNAME = 'DFW4' AND LENGTH != 0 AND WEIGHT != 0;
# Out:
#          PARCELKEY FACILITYNAME  MACHINEID            CREATIONTIME  LENGTH  \
# 0        642786338         DFW4          7 2021-02-10 01:11:55.320   166.0
# 1        642786339         DFW4          7 2021-02-10 01:11:55.330   233.0
# 2        642786344         DFW4          8 2021-02-10 01:11:23.603   327.0
# 3        642786354         DFW4          7 2021-02-10 01:11:56.037   313.0
# 4        642786355         DFW4          8 2021-02-10 01:11:56.220   305.0
# ...            ...          ...        ...                     ...     ...
# 1181084  634890343         DFW4          7 2021-02-01 17:46:09.100   159.0
# 1181085  634890345         DFW4          7 2021-02-01 17:46:41.857   459.0
# 1181086  634890366         DFW4          7 2021-02-01 17:46:10.057   242.0
# 1181087  634890368         DFW4          7 2021-02-01 17:46:42.613   397.0
# 1181088  634890377         DFW4          8 2021-02-01 17:46:42.803   272.0
#
#          WIDTH  HEIGHT  WEIGHT
# 0        154.0   159.0   647.0
# ...

# %%
DFW9.to_csv('DFW9.csv')

# %%
# %%snowflakes DFW10
#
# SELECT
#     PARCELKEY, FACILITYNAME, MACHINEID, CREATIONTIME, LENGTH, WIDTH, HEIGHT, WEIGHT
# FROM
#     "FDR_DWH_DB_PROD"."PARCELAUTOMATION"."PARCEL"
# WHERE
#     CREATIONTIME >= '2021-02-15' AND CREATIONTIME < '2021-03-01' AND FACILITYNAME = 'DFW4' AND LENGTH != 0 AND WEIGHT != 0;
# Out:
#         PARCELKEY FACILITYNAME  MACHINEID            CREATIONTIME  LENGTH  \
# 0       650101426         DFW4          7 2021-02-19 01:37:34.270   325.0
# 1       650101430         DFW4          7 2021-02-19 01:38:04.980   303.0
# 2       650101438         DFW4          8 2021-02-19 01:37:02.757   191.0
# 3       650101439         DFW4          7 2021-02-19 01:37:35.203   440.0
# 4       650101448         DFW4          7 2021-02-19 01:37:36.270   300.0
# ...           ...          ...        ...                     ...     ...
# 773169  650264647         DFW4          7 2021-02-19 13:17:25.310   435.0
# 773170  650264788         DFW4          7 2021-02-19 13:17:32.903   382.0
# 773171  650264823         DFW4          7 2021-02-19 13:18:16.730   282.0
# 773172  650264976         DFW4          7 2021-02-19 13:17:44.530   273.0
# 773173  650265118         DFW4          7 2021-02-19 13:17:52.643   184.0
#
#         WIDTH  HEIGHT  WEIGHT
# 0        88.0   278.0   887.0
# ...

# %%
DFW10.to_csv('DFW10.csv')

# %%
# %%snowflakes DFW11
#
# SELECT
#     PARCELKEY, FACILITYNAME, MACHINEID, CREATIONTIME, LENGTH, WIDTH, HEIGHT, WEIGHT
# FROM
#     "FDR_DWH_DB_PROD"."PARCELAUTOMATION"."PARCEL"
# WHERE
#     CREATIONTIME >= '2021-03-01' AND CREATIONTIME < '2021-03-15' AND FACILITYNAME = 'DFW4' AND LENGTH != 0 AND WEIGHT != 0;
# Out:
#         PARCELKEY FACILITYNAME  MACHINEID            CREATIONTIME  LENGTH  \
# 0       658556289         DFW4          7 2021-03-02 03:08:30.910   214.0
# 1       658556300         DFW4          7 2021-03-02 03:09:02.810   217.0
# 2       658556310         DFW4          7 2021-03-02 03:08:32.750   237.0
# 3       658556315         DFW4          7 2021-03-02 03:08:34.173   254.0
# 4       658556319         DFW4          7 2021-03-02 03:09:04.300   260.0
# ...           ...          ...        ...                     ...     ...
# 967457  665008562         DFW4          7 2021-03-10 00:18:18.613   272.0
# 967458  665008580         DFW4          7 2021-03-10 00:18:19.427   251.0
# 967459  665008581         DFW4          7 2021-03-10 00:18:19.610   215.0
# 967460  665008592         DFW4          7 2021-03-10 00:18:19.770   316.0
# 967461  665008598         DFW4          7 2021-03-10 00:18:20.517   358.0
#
#         WIDTH  HEIGHT  WEIGHT
# 0        29.0   124.0   178.0
# ...

# %%
DFW11.to_csv('DFW11.csv')

# %%
# %%snowflakes DFW12
#
# SELECT
#     PARCELKEY, FACILITYNAME, MACHINEID, CREATIONTIME, LENGTH, WIDTH, HEIGHT, WEIGHT
# FROM
#     "FDR_DWH_DB_PROD"."PARCELAUTOMATION"."PARCEL"
# WHERE
#     CREATIONTIME >= '2021-03-15' AND CREATIONTIME < '2021-04-01' AND FACILITYNAME = 'DFW4' AND LENGTH != 0 AND WEIGHT != 0;
# Out:
#          PARCELKEY FACILITYNAME  MACHINEID            CREATIONTIME  LENGTH  \
# 0        677745877         DFW4          8 2021-03-24 23:13:39.053   304.0
# 1        677745883         DFW4          7 2021-03-24 23:14:11.163   306.0
# 2        677745892         DFW4          7 2021-03-24 23:13:39.887   305.0
# 3        677745907         DFW4          8 2021-03-24 23:14:42.373   461.0
# 4        677745908         DFW4          7 2021-03-24 23:14:12.510   305.0
# ...            ...          ...        ...                     ...     ...
# 1367124  679719885         DFW4          7 2021-03-26 19:31:40.890   127.0
# 1367125  679719892         DFW4          7 2021-03-26 19:31:41.760   293.0
# 1367126  679719897         DFW4          8 2021-03-26 19:32:12.187   493.0
# 1367127  679719898         DFW4          7 2021-03-26 19:31:42.240   288.0
# 1367128  679719906         DFW4          7 2021-03-26 19:31:10.673   106.0
#
#          WIDTH  HEIGHT  WEIGHT
# 0         94.0   300.0   488.0
# ...

# %%
DFW12.to_csv('DFW12.csv')

# %%
import pandas as pd

DFW = pd.read_csv('dfw.csv')
DFW3 = pd.read_csv('DFW8.csv')
DFW4 = pd.read_csv('DFW9.csv')
DFW5 = pd.read_csv('DFW10.csv')
DFW6 = pd.read_csv('DFW11.csv')
DFW7 = pd.read_csv('DFW12.csv')

DFW = DFW.append(DFW3)
DFW = DFW.append(DFW4)
DFW = DFW.append(DFW5)
DFW = DFW.append(DFW6)
DFW = DFW.append(DFW7)

DFW.to_csv('dfw.csv')

# %%
# %%snowflakes vs
#
# SELECT
#     P.FACILITYNAME, P.CREATIONTIME, P.MACHINEID, P.LENGTH, P.WIDTH, P.HEIGHT, P.WEIGHT,
#     B.BARCODE, PF.MERCHANT, PF.MERCHANT_ORG_KEY
# FROM
#     FDR_DB.FDR_AUTOMATION.PARCEL P
# INNER JOIN
#     FDR_DB.FDR_AUTOMATION.BARCODE B
# ON
#     B.PARCELKEY = P.PARCELKEY
# INNER JOIN
#     FDR_DB.FDR_EWS.PARCEL_FACILITY PF
# ON
#     P.FACILITYNAME = PF.FACILITY_NAME
# AND
#     B.BARCODE = PF.PRIMARY_BARCODE
# WHERE
#     PF.MERCHANT = 'Victoria Secret'
# AND
#     P.FACILITYNAME = 'DFW4';
# Out:
#         FACILITYNAME            CREATIONTIME  MACHINEID  LENGTH  WIDTH  \
# 0               DFW4 2020-08-26 12:31:42.273          7   266.0   78.0
# 1               DFW4 2020-08-26 12:32:15.527          7   339.0  117.0
# 2               DFW4 2020-08-26 12:32:14.100          7   224.0   82.0
# 3               DFW4 2020-08-26 12:33:40.293          7   344.0  100.0
# 4               DFW4 2020-08-26 12:34:24.913          7   251.0   65.0
# ...              ...                     ...        ...     ...    ...
# 1268876         DFW4 2020-10-10 01:02:28.707          7   329.0  102.0
# 1268877         DFW4 2020-12-30 15:53:53.497          8   238.0   89.0
# 1268878         DFW4 2020-12-30 16:02:52.193          7   306.0   92.0
# 1268879         DFW4 2020-12-30 15:27:43.647          8   214.0   54.0
# 1268880         DFW4 2020-12-30 15:49:45.647          8   221.0   47.0
#
#          HEIGHT  WEIGHT                         BARCODE         MERCHANT  \
# ...

# %%
vs.to_csv('dfw_vs.csv')
